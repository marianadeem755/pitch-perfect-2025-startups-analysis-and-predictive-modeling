# %% [markdown]
# # **💡Pitch Perfect 2025: Startup Pitches, Data Analysis & Predictive Modeling📈**

# %% [markdown]
# ## **About Startup Company One-Line Pitches Dataset**
#
# - This dataset contains startups (one-line pitches) along with key information about most common company. It is designed for  data cleaning, analysis, text processing, and predictive modeling.
# - This Dataset consists of
# - Rows: 3,069 startups
# - Columns: 15 features
#
# - **Data Types:** This Dataset includes both numeric and categorical columns
#
# We can use this dataset for:
# - **Text analysis:** Extract keywords or classify startup pitches
# - **Prediction:** Estimate funding amount, team size, or funding stage
# - **Visualization**: Create charts showing sector growth, funding trends, or employee distribution

# %% [markdown]
# ## **About Dataset Columns**

# %% [markdown]
# | Column | Type | Description |
# |--------|------|-------------|
# | **Startup_ID** | Integer | Unique ID for each startup |
# | **Company_Name** | String | The startup’s name or brand |
# | **Industry** | Category | Sector of the startup (e.g., AI & ML, FinTech, HealthTech, SaaS, E-commerce) |
# | **One_Line_Pitch** | String | Short value proposition describing the startup |
# | **Founding_Year** | Integer | Year when the startup was founded |
# | **Headquarters_Location** | String | City and country where the startup operates or is registered |
# | **Funding_Stage** | Category | Current funding stage (Seed, Series A–D, IPO) |
# | **Last_Funding_Amount_USD_Millions** | Float | Most recent funding in millions USD (may have missing values) |
# | **Number_of_Employees** | Integer | Approximate team size (may have missing values) |
# | **Website** | String | Official company website (may have missing values) |
# | **LinkedIn_Profile** | String | LinkedIn page of the company (may have missing values) |
# | **Twitter_Handle** | String | Official Twitter/X handle (may have missing values) |
# | **CEO_Name** | String | Name of the CEO or founder |
# | **Core_Technology** | Category | Main technology used by the startup (e.g., AI, NLP, IoT, Blockchain, Cloud) |
# | **Market_Size_Billion_USD** | Float | Estimated size of the market in billions USD (may have missing values) |

# %% [markdown]
# ## **About Author**

# %% [markdown]
# * Hi I'm Maria Nadeem, a passionate Data Scientist with strong interest in exploring and applying diverse data science techniques.
# * I'm dedicated to make impactful decisions through data and building robust machine learning and deep learning models, I actively create  projects and contributeby applying and powerful algorithms such as RRandom Forest, Decision Tree, Knn, XGBoost, LightGBM, CatBoost and Neural Networks to drive high performing predictions and solve complex challenges.
# * I'm excited to share my latest project startup_company_one_line_pitches predictions and analysis.
# * In this Notebook i first explore the whole Data then do Feature Endgineering,Feature Normalization and also do Data preprocessing
# * And then Train KNN, random Forest, Decision Tree and implement Hyperparameter Tuning and Random Search cv and get best results

# %% [markdown]
# | Name               | Email                                               | LinkedIn                                                  | GitHub                                           | Kaggle                                        |
# |--------------------|-----------------------------------------------------|-----------------------------------------------------------|--------------------------------------------------|-----------------------------------------------|
# | **Maria Nadeem**  | marianadeem755@gmail.com | <a href="https://www.linkedin.com/in/maria-nadeem-4994122aa/" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/LinkedIn-%2300A4CC.svg?style=for-the-badge&logo=LinkedIn&logoColor=white" alt="LinkedIn Badge"></a> | <a href="https://github.com/marianadeem755" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/GitHub-%23FF6F61.svg?style=for-the-badge&logo=GitHub&logoColor=white" alt="GitHub Badge"></a> | <a href="https://www.kaggle.com/marianadeem755" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/Kaggle-%238a2be2.svg?style=for-the-badge&logo=Kaggle&logoColor=white" alt="Kaggle Badge"></a> |

# %% [markdown]
# ## **Import Libraries**

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# import plotly.io as pio
# pio.renderers.default = 'iframe_connected'
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy.stats import randint
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.ensemble import VotingClassifier, StackingClassifier
# ignore warnings
import warnings
warnings.filterwarnings("ignore")
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ## **Load and Display the Dataset**

# %%
df=pd.read_csv("startup_company_one_line_pitches.csv")
df.head(10)
# Out:
#    Startup_ID                     Company_Name       Industry  \
# 0           1  Rodriguez, Figueroa and Sanchez   Social Media
# 1           2                   Davis and Sons         EdTech
# 2           3                   Blake and Sons           SaaS
# 3           4                       Howard LLC            IoT
# 4           5              Calderon-Montgomery       Mobility
# 5           6                   Delacruz Group     HealthTech
# 6           7          Wong, Lynch and Jackson         Gaming
# 7           8                        Perez Inc     E-commerce
# 8           9                       Rios Group  Cybersecurity
# 9          10                       Hurst-Ross     HealthTech
#
#                                       One_Line_Pitch  Founding_Year  \
# 0  Social currencies incentivizing participation ...           2016
# 1  Predictive dropout prevention powered by analy...           2014
# 2  Cross-border collaboration SaaS optimized for ...           2018
# ...

# %% [markdown]
# ## **Lets Check the Dataset Shape and Structure**

# %%
# Dataset Structure and shape
print("Shape of the Dataset:", df.shape)
print("====================================")
print("Dataset Structure")
display(df.info())
# Out:
# Shape of the Dataset: (3069, 15)
# ...
# Dataset Structure
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3069 entries, 0 to 3068
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Startup_ID                        3069 non-null   int64
#  1   Company_Name                      3069 non-null   object
#  2   Industry                          3069 non-null   object
#  3   One_Line_Pitch                    3069 non-null   object
#  4   Founding_Year                     3069 non-null   int64
#  5   Headquarters_Location             3069 non-null   object
#  6   Funding_Stage                     2733 non-null   object
#  7   Last_Funding_Amount_USD_Millions  2174 non-null   float64
#  8   Number_of_Employees               2608 non-null   float64
#  9   Website                           3008 non-null   object
#  10  LinkedIn_Profile                  3008 non-null   object
# ...

# %% [markdown]
# ## **Lets Display Dataset Columns**

# %%
# Dataset columns
df.columns
# Out:
# Index(['Startup_ID', 'Company_Name', 'Industry', 'One_Line_Pitch',
#        'Founding_Year', 'Headquarters_Location', 'Funding_Stage',
#        'Last_Funding_Amount_USD_Millions', 'Number_of_Employees', 'Website',
#        'LinkedIn_Profile', 'Twitter_Handle', 'CEO_Name', 'Core_Technology',
#        'Market_Size_Billion_USD'],
#       dtype='object')

# %% [markdown]
# ## **Display Summary Statistics**

# %%
# Display Summary Statistics
print("Summary Statistics of Dataset")
display(df.describe())
# Out:
# Summary Statistics of Dataset
#         Startup_ID  Founding_Year  Last_Funding_Amount_USD_Millions  \
# count  3069.000000    3069.000000                       2174.000000
# mean   1535.000000    2016.578364                        142.266136
# std     886.088314       5.211136                        207.375894
# min       1.000000    2008.000000                          0.050000
# 25%     768.000000    2012.000000                          4.445000
# 50%    1535.000000    2017.000000                         52.940000
# 75%    2302.000000    2021.000000                        189.900000
# max    3069.000000    2025.000000                        998.460000
#
#        Number_of_Employees  Market_Size_Billion_USD
# count          2608.000000               2855.00000
# mean            575.139187                 58.28021
# std             940.514767                 41.54179
# min               1.000000                  5.00000
# 25%              29.000000                 20.00000
# ...

# %% [markdown]
# ## **Check the Missing values and percentage of Missing values present in the Dataset**

# %%
# Check the Missing values present in the Dataset
print("Missing values present in the Dataset are:\n", df.isnull().sum())
print("=========================================================================")
print("Lets Display Missing values percentage:\n", df.isnull().sum()/len(df)*100)
# Out:
# Missing values present in the Dataset are:
#  Startup_ID                            0
# Company_Name                          0
# Industry                              0
# One_Line_Pitch                        0
# Founding_Year                         0
# Headquarters_Location                 0
# Funding_Stage                       336
# Last_Funding_Amount_USD_Millions    895
# Number_of_Employees                 461
# Website                              61
# LinkedIn_Profile                     61
# Twitter_Handle                       99
# CEO_Name                              0
# Core_Technology                       0
# Market_Size_Billion_USD             214
# dtype: int64
# ...
# Lets Display Missing values percentage:
#  Startup_ID                           0.000000
# Company_Name                         0.000000
# Industry                             0.000000
# One_Line_Pitch                       0.000000
# Founding_Year                        0.000000
# ...

# %% [markdown]
# ## **Impute Missing values using Iterative Imputer and Simple Imputer**

# %%
# Iterative Imputer for high missing
iter_imputer = IterativeImputer(random_state=42)
df[['Last_Funding_Amount_USD_Millions']] = iter_imputer.fit_transform(df[['Last_Funding_Amount_USD_Millions']])

# Simple Imputer (median) for moderate missing
simple_imputer = SimpleImputer(strategy='median')
df[['Number_of_Employees']] = simple_imputer.fit_transform(df[['Number_of_Employees']])

# %% [markdown]
# ## **Impute Missing values using Mean, Median and Mode**

# %%
# Categorical columns (mode)
cat_cols = ['Funding_Stage', 'Website', 'LinkedIn_Profile', 'Twitter_Handle']
for col in cat_cols:
    mode_val = df[col].mode()[0]
    df[col].fillna(mode_val, inplace=True)

# Numerical columns (median or mean)
# Median
median_cols = ['Last_Funding_Amount_USD_Millions', 'Number_of_Employees']
for col in median_cols:
    median_val = df[col].median()
    df[col].fillna(median_val, inplace=True)

# Mean
mean_cols = ['Market_Size_Billion_USD']
for col in mean_cols:
    mean_val = df[col].mean()
    df[col].fillna(mean_val, inplace=True)

# %% [markdown]
# ## **Check the Missing values after imputation**

# %%
# Check the Missing values present in the Dataset after imputation
print("Missing values present in the Dataset are:\n", df.isnull().sum())
print("=========================================================================")
print("Lets Display Missing values percentage:\n", df.isnull().sum()/len(df)*100)
# Out:
# Missing values present in the Dataset are:
#  Startup_ID                          0
# Company_Name                        0
# Industry                            0
# One_Line_Pitch                      0
# Founding_Year                       0
# Headquarters_Location               0
# Funding_Stage                       0
# Last_Funding_Amount_USD_Millions    0
# Number_of_Employees                 0
# Website                             0
# LinkedIn_Profile                    0
# Twitter_Handle                      0
# CEO_Name                            0
# Core_Technology                     0
# Market_Size_Billion_USD             0
# dtype: int64
# ...
# Lets Display Missing values percentage:
#  Startup_ID                          0.0
# Company_Name                        0.0
# Industry                            0.0
# One_Line_Pitch                      0.0
# Founding_Year                       0.0
# Headquarters_Location               0.0
# Funding_Stage                       0.0
# ...

# %% [markdown]
# ## **Lets Display the Statistics of Numeric Columns**

# %%
# Numeric columns
numeric_cols = ['Founding_Year', 'Last_Funding_Amount_USD_Millions', 'Number_of_Employees', 'Market_Size_Billion_USD']

# Using NumPy for statistics
for col in numeric_cols:
    print("=================================================")
    print(f"Column: {col}")
    print("Mean:", np.mean(df[col]))
    print("Median:", np.median(df[col]))
    print("Min:", np.min(df[col]))
    print("Max:", np.max(df[col]))
    print("\n")
# Out:
# ...
# Column: Founding_Year
# Mean: 2016.5783642880417
# Median: 2017.0
# Min: 2008
# Max: 2025
#
#
# ...
# Column: Last_Funding_Amount_USD_Millions
# Mean: 116.21631801889866
# Median: 52.94
# Min: 0.05
# Max: 998.46
#
#
# ...
# Column: Number_of_Employees
# Mean: 517.2867383512545
# Median: 190.0
# Min: 1.0
# Max: 4977.0
#
#
# ...
# Column: Market_Size_Billion_USD
# Mean: 58.280210157618214
# Median: 58.280210157618214
# Min: 5.0
# Max: 150.0

# %% [markdown]
# ## **Lets take insights of Industry and Funding Stage Columns**

# %%
# Industry Insights
industry_counts = df['Industry'].value_counts()

print("Startups by Industry")
print("Top Industry:", industry_counts.idxmax(), "with", industry_counts.max(), "startups")
print("Bottom Industry:", industry_counts.idxmin(), "with", industry_counts.min(), "startups")
print("Average startups per industry:", np.mean(industry_counts))
print("Median startups per industry:", np.median(industry_counts))
print("===================================================================")

# Funding Stage Insights
funding_counts = df['Funding_Stage'].value_counts()

print("Startups by Funding Stage")
print("Most common stage:", funding_counts.idxmax(), "with", funding_counts.max(), "startups")
print("Least common stage:", funding_counts.idxmin(), "with", funding_counts.min(), "startups")
print("Average startups per stage:", np.mean(funding_counts))
print("Median startups per stage:", np.median(funding_counts))
print("=======================================================================")

# Overall Statistics
print("Overall Startup Distribution")
print("Total startups:", len(df))
print("Unique industries:", df['Industry'].nunique())
print("Unique funding stages:", df['Funding_Stage'].nunique())
# Out:
# Startups by Industry
# Top Industry: Gaming with 223 startups
# Bottom Industry: IoT with 189 startups
# Average startups per industry: 204.6
# Median startups per industry: 201.0
# ...
# Startups by Funding Stage
# Most common stage: Seed with 691 startups
# Least common stage: Series B with 333 startups
# Average startups per stage: 383.625
# Median startups per stage: 338.0
# ...
# Overall Startup Distribution
# Total startups: 3069
# Unique industries: 15
# Unique funding stages: 8

# %% [markdown]
# ## **Lets visualize Number of Startups per Industry and Startups by Funding Stage**

# %%
# color palatte
Warm_Pastel = sns.color_palette([
    "#FF6F61", "#6B5B95", "#88B04B", "#F7CAC9", "#92A8D1", 
    "#FFA500", "#00CED1", "#FF1493", "#8B0000", "#4682B4",
    "#32CD32", "#FFD700", "#FF4500"
])

# Palette for Funding Stage (5 colors)
Cool_Vivid = sns.color_palette(["#955251", "#B565A7", "#009B77", "#DD4124", "#45B8AC"])

# Count of startups by Industry
plt.figure(figsize=(14,6))
ax1 = sns.countplot(
    x='Industry', 
    data=df, 
    order=df['Industry'].value_counts().index, 
    palette=Warm_Pastel
)
plt.title("Number of Startups per Industry", fontsize=16)
plt.xlabel("Industry", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45, ha='right')  # rotate x-ticks

# Annotate values above bars
for p in ax1.patches:
    ax1.annotate(f'{p.get_height()}', 
                 (p.get_x() + p.get_width() / 2., p.get_height()), 
                 ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()


# Count of startups by Funding Stage
plt.figure(figsize=(10,5))
ax2 = sns.countplot(
    x='Funding_Stage', 
    data=df, 
    order=df['Funding_Stage'].value_counts().index, 
    palette=Cool_Vivid
)
plt.title("Startups by Funding Stage", fontsize=16)
plt.xlabel("Funding Stage", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45, ha='right')  # rotate x-ticks

# Annotate values above bars
for p in ax2.patches:
    ax2.annotate(f'{p.get_height()}', 
                 (p.get_x() + p.get_width() / 2., p.get_height()), 
                 ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Startup Insights: Industries & Funding Observations
# ### Startups by Industry
# > **Leaders:** According to this Dataset, the Gaming and Social Media dominate over **200 startups each**.
# > **Strong Presence:** The Fintech of about 197 and the HealthTech of about 210 also show significant activity.
# > **Smaller Fields:** IoT have fewer startups in comparison to other.
#
# ### Startups by Funding Stage
# > **Seed Stage dominates** According to this Dataset Seed Stage dominates with about **691 startups** as they have frequency Distribution Count of about 691.
# > **Series A and Series B** Series A and Series B are also strong to about 336 and about 333.
# > **Later Stages (Series C and beyond)** Later Stages (Series C and beyond) also have also 340 and 335 startups, which highlight the process of early growth.
#
# > Hence, Gaming and Social Media **lead in startup numbers**, then mobility have 221.0 and cybersecurity ahve 231.0
# > According to this Dataset average startups per industry is 204.6
# > According to this Dataset Median startups per industry is 201.0
# > And According to this Dataset the Most common stage is Seed with 691 startups
# > while Least common stage is Series B with 333 startups
# > Hence, Average startups per stage is 383.625 and Median startups per stage is 338.0
# > There are total 3069 startups, 15 Unique industries and 8 Unique funding stages

# %% [markdown]
# ## **Statistics by Funding Stage**

# %%
# Numeric columns of interest
numeric_cols = ["Number_of_Employees", "Last_Funding_Amount_USD_Millions", "Market_Size_Billion_USD"]

# Overall Descriptive Statistics

print("Overall Statistics")
overall_stats = df[numeric_cols].agg(["mean", "median", "min", "max"])
display(overall_stats)
print("============================================================================")

# Funding Stage Perspective

print("Statistics by Funding Stage")
funding_stats = df.groupby("Funding_Stage")[numeric_cols].agg(["mean", "median", "min", "max", "std", "count"])
display(funding_stats)
# Out:
# Overall Statistics
#         Number_of_Employees  Last_Funding_Amount_USD_Millions  \
# mean             517.286738                        116.216318
# median           190.000000                         52.940000
# min                1.000000                          0.050000
# max             4977.000000                        998.460000
#
#         Market_Size_Billion_USD
# mean                   58.28021
# median                 58.28021
# min                     5.00000
# max                   150.00000
# ...
# Statistics by Funding Stage
#                Number_of_Employees                                            \
#                               mean  median    min     max          std count
# Funding_Stage
# IPO                    2256.348214  2221.5  190.0  4977.0  1528.594971   336
# Pre-Seed                 35.411594     6.0    1.0   190.0    68.195716   345
# Private Equity          954.359773   892.0  190.0  2000.0   574.488521   353
# ...

# %% [markdown]
# ## **Lets Display Statistics by Industry, Startups by Employees and Funding Amount**

# %%
# Industry Perspective
print("Statistics by Industry")
industry_stats = df.groupby("Industry")[numeric_cols].agg(["mean", "median", "min", "max","count"])
display(industry_stats)

print("=============================================================")
# Top & Bottom Companies
print("Top & Bottom Companies")
print("\nTop 5 Startups by Funding:")
display(df.nlargest(5, "Last_Funding_Amount_USD_Millions")[["Industry", "Funding_Stage", "Last_Funding_Amount_USD_Millions"]])
print("=============================================================")
print("Bottom 5 Startups by Funding:")
display(df.nsmallest(5, "Last_Funding_Amount_USD_Millions")[["Industry", "Funding_Stage", "Last_Funding_Amount_USD_Millions"]])
print("=============================================================")
print("\nTop 5 Startups by Employees:")
display(df.nlargest(5, "Number_of_Employees")[["Industry", "Funding_Stage", "Number_of_Employees"]])
# Out:
# Statistics by Industry
#                       Number_of_Employees                            \
#                                      mean median  min     max count
# Industry
# AI & Machine Learning          631.064677  190.0  1.0  4963.0   201
# Blockchain                     469.790816  190.0  1.0  4908.0   196
# CleanTech                      551.290155  190.0  1.0  4935.0   193
# Cybersecurity                  525.718310  190.0  1.0  4850.0   213
# E-commerce                     468.590909  190.0  1.0  4686.0   198
# EdTech                         543.578947  190.0  1.0  4461.0   209
# FinTech                        424.791878  186.0  1.0  4393.0   197
# Food Tech                      508.838542  190.0  1.0  4977.0   192
# Gaming                         470.968610  190.0  2.0  4868.0   223
# HealthTech                     392.461905  190.0  1.0  4645.0   210
# IoT                            422.740741  190.0  1.0  4060.0   189
# ...

# %% [markdown]
# ## **Lets do the Cross Tab Analysis: Funding Stage and Industry**

# %%
# Cross Tab Analysis: Funding Stage and Industry
print("Cross Analysis: Funding Stage and Industry")
cross_tab = df.groupby(["Funding_Stage", "Industry"]).size().unstack(fill_value=0)
display(cross_tab)
# Out:
# Cross Analysis: Funding Stage and Industry
# Industry        AI & Machine Learning  Blockchain  CleanTech  Cybersecurity  \
# Funding_Stage
# IPO                                30          22         17             22
# Pre-Seed                           18          19         18             30
# Private Equity                     23          21         21             29
# Seed                               45          43         45             46
# Series A                           21          25         17             23
# Series B                           24          25         20             14
# Series C                           23          23         28             23
# Series D                           17          18         27             26
#
# Industry        E-commerce  EdTech  FinTech  Food Tech  Gaming  HealthTech  \
# Funding_Stage
# IPO                     17      24       25         20      20          18
# ...

# %% [markdown]
# ## **Lets Visualize Funding Amount vs Number of Employees**

# %%
# Define a custom vibrant color palette for Funding Stage
Funding_Stage_Palette = [
    "#FF6F61", "#6B5B95", "#88B04B", "#F7CAC9", "#92A8D1",
    "#FFA500", "#00CED1", "#FF1493", "#8B0000"
]

fig = px.scatter(
    df,
    x="Number_of_Employees",
    y="Last_Funding_Amount_USD_Millions",
    color="Funding_Stage",
    size="Market_Size_Billion_USD",
    color_discrete_sequence=Funding_Stage_Palette,
    size_max=20,  # max bubble size
    hover_data=["Industry", "Number_of_Employees", "Last_Funding_Amount_USD_Millions", "Market_Size_Billion_USD"]
)

fig.update_layout(
    title="Funding Amount vs Number of Employees",
    xaxis_title="Number of Employees",
    yaxis_title="Funding Amount (Millions USD)",
    legend_title="Funding Stage",
    template="plotly_white",
    width=900,
    height=600
)

fig.show()

# %% [markdown]
# ## Observations:
# ## 1. Employees vs Funding Amount  Insights
# > According to this Dataset Many Startups with higher funding generally tend to have more employees, though there are some exceptions exist and there are only a few small teams with large fundings.
# > Many Early funding stages such as Seed usually show lower and very less in higher funding amounts and smaller team sizes.
# > The Later stages such as Series A, B etc display very less team sizes and lower funding.
#
#
# ## 2. Role of Funding Stage
# > **Seed stage companies** Many Seed stage companies cluster at lower funding and smaller teams and only few of them at higher it means they have low fundings and small team members.
# > **Series A and B companies** are also less spread outand they have lesser employee counts and lower funding.
# > **Series C and beyond** have both low and high market size and fundings.
#
#
# ## 3. Market Size Perspective
# > According to this Dataset many industries are operating in bigger markets.
# > Some of the industries show smaller employee counts but they are still operating in very large markets, and suggesting early entrants in high potential areas.
# > The Established industries tends to show both larger teams and larger markets.
# >
# ## 4. Industry Perspective
# > Certain industries such as **e-commerce, fintech, AI & Machine Learning** appear across a wide funding and employee range, this shows the diversity in companies maturity.
# > Many Specialized industries such as **Gaming	HealthTech** appear less frequently, but when they do, they often show relatively higher funding amounts for their team size.

# %% [markdown]
# ## **Lets take insights of Funding Distribution per Industry & Funding Stage&**

# %%
# Funding Distribution per Industry
industry_stats = df.groupby("Industry")["Last_Funding_Amount_USD_Millions"].agg(["mean", "median", "std", "max", "min"])
print("Funding Distribution by Industry")
print("Industry with highest average funding:", industry_stats["mean"].idxmax(), "is", industry_stats["mean"].max())
print("Industry with lowest average funding:", industry_stats["mean"].idxmin(), "is", industry_stats["mean"].min())
print("===============================================================")

# Funding Stage Insights
stage_stats = df.groupby("Funding_Stage")["Last_Funding_Amount_USD_Millions"].agg(["mean", "median", "std", "max", "min"])
print("Funding Stage Performance")
print("Stage with highest median funding:", stage_stats["median"].idxmax(), "is", stage_stats["median"].max())
print("Stage with lowest median funding:", stage_stats["median"].idxmin(), "is", stage_stats["median"].min())
print("===============================================================")

# Funding Inequality (Max/Min Ratio per Industry)
industry_stats["funding_range_ratio"] = industry_stats["max"] / industry_stats["min"].replace(0, np.nan)
print("Funding Inequality Across Industries")
print("Industry with highest funding inequality:", industry_stats["funding_range_ratio"].idxmax(), "is", industry_stats["funding_range_ratio"].max())
print("Industry with lowest funding inequality:", industry_stats["funding_range_ratio"].idxmin(), "is", industry_stats["funding_range_ratio"].min())
print("===============================================================")

# Overall Statistics
print("Overall Startup Funding Distribution")
print("Total funding (sum):", df["Last_Funding_Amount_USD_Millions"].sum())
print("Average funding per startup:", df["Last_Funding_Amount_USD_Millions"].mean())
print("Median funding per startup:", df["Last_Funding_Amount_USD_Millions"].median())
print("Max funding received:", df["Last_Funding_Amount_USD_Millions"].max(), "in Industry:", df.loc[df["Last_Funding_Amount_USD_Millions"].idxmax(), "Industry"])
# Out:
# Funding Distribution by Industry
# Industry with highest average funding: Social Media is 128.56009009009009
# Industry with lowest average funding: E-commerce is 103.12742424242424
# ...
# Funding Stage Performance
# Stage with highest median funding: IPO is 444.695
# Stage with lowest median funding: Pre-Seed is 1.01
# ...
# Funding Inequality Across Industries
# Industry with highest funding inequality: PropTech is 19524.8
# Industry with lowest funding inequality: Food Tech is 1679.5862068965519
# ...
# Overall Startup Funding Distribution
# Total funding (sum): 356667.88
# Average funding per startup: 116.21631801889866
# Median funding per startup: 52.94
# Max funding received: 998.46 in Industry: Gaming

# %% [markdown]
# ## **Lets Visualize Distribution of Funding Amount by Industry**

# %%
# Get all industries
industries = df['Industry'].unique()
n_cols = 3
n_rows = (len(industries) + n_cols - 1) // n_cols

# Create subplot figure
fig = make_subplots(
    rows=n_rows, cols=n_cols,
    subplot_titles=industries,
    shared_yaxes=False,
    horizontal_spacing=0.05,
    vertical_spacing=0.09
)

# Custom color palette for Funding Stage
Funding_Stage_Palette = ["#FF6F61", "#6B5B95", "#88B04B", "#F7CAC9", "#92A8D1",
                         "#FFA500", "#00CED1", "#FF1493", "#8B0000"]

# Add boxplots
for i, industry in enumerate(industries):
    row = (i // n_cols) + 1
    col = (i % n_cols) + 1
    for j, stage in enumerate(df['Funding_Stage'].unique()):
        industry_data = df[(df['Industry']==industry) & (df['Funding_Stage']==stage)]
        y_vals = industry_data['Last_Funding_Amount_USD_Millions']
        
        # Compute summary statistics
        min_val = np.min(y_vals)
        q1 = np.percentile(y_vals, 25)
        median = np.median(y_vals)
        mean = np.mean(y_vals)
        q3 = np.percentile(y_vals, 75)
        max_val = np.max(y_vals)
        
        fig.add_trace(
            go.Box(
                y=y_vals,
                name=stage,
                marker_color=Funding_Stage_Palette[j % len(Funding_Stage_Palette)],
                boxpoints='all',
                jitter=0.5,
                pointpos=-1.8,
                showlegend=(i==0),
                hovertemplate=(
                    f'<b>Industry:</b> {industry}<br>'
                    f'<b>Funding Stage:</b> {stage}<br>'
                    f'<b>Min:</b> {min_val}<br>'
                    f'<b>Q1:</b> {q1}<br>'
                    f'<b>Median:</b> {median}<br>'
                    f'<b>Mean:</b> {mean}<br>'
                    f'<b>Q3:</b> {q3}<br>'
                    f'<b>Max:</b> {max_val}<extra></extra>'
                )
            ),
            row=row, col=col
        )
    
    # Customize x-axis
    fig.update_xaxes(title_text="Funding Stage", row=row, col=col, tickangle=-45)
    
    # Customize y-axis only for first column
    if col == 1:
        fig.update_yaxes(title_text="Funding Amount (Millions USD)", row=row, col=col, showticklabels=True)
    else:
        fig.update_yaxes(title_text="", row=row, col=col, showticklabels=True)

# Update layout
fig.update_layout(
    height=350*n_rows,
    width=1200,
    title_text="Distribution of Funding Amount by Industry",
    showlegend=True
)

fig.show()

# %% [markdown]
# # Funding Distribution by Industry
#
# ## Funding Distribution (Summary Numbers)
#
# ### Industries
# > The **highest average funding** is in **Social Media** are of about 155.9.
# > The **lowest average funding** is in **E-commerce**  are of about 130.6.
#
# ### Funding Stages
# > The **stage with the highest median funding** is **IPO**  are of about 444.7.
# > The **stage with the lowest median funding** is **Pre-Seed**  are of about 1.0.
#
# ### Funding Inequality (Differences Within Industries)
# > The **industry with the biggest funding gap** (inequality) is **PropTech**  are of about 19524.8.
# > The **industry with the smallest gap** is **FoodTech**  are of about 1679.6.
#
# ### Overall Startup Funding
# > **Total funding (all startups combined):**  are of about 436,615
# > **Average funding per startup:**  are of about 142.3
# > **Median funding per startup:** are of about 142.3
# > **Maximum funding:** in **Gaming** m aximum funding received of about 998.5.
#
# ## Industry-Level Insights
# > **Social Media**: According to this Dataset some of the highest funding, especially strong in **IPO**.
# > **EdTech**: And the Moderate funding overall according to this Dataset is of **private Equity**.
# > **SaaS**: Saas Funding stage is stronger in the case of **IPO**.
# > **IoT** → Balanced funding, and it peak in case of **IPO**.
# > **Mobility**: The Mobility Big funding in case of **IPO**, but it drops in Series B then again its fundings increases.
# > **HealthTech**: High funding, especially in case of ***IPO* and reduce in series B.
# > **Gaming**: Strong in case of **IPO**, but declines in **Series B**.
# > **E-commerce**: High funding across **IPO**, while reduce much in **Series B**, moderate funding in case of **private Equity**.
# > **Cybersecurity**: Moderate levels in case of **private Equity** and in **Series D** and High funding across **IPO**.
# > **PropTech**: Fairly balanced, and High funding across **IPO**.
# > **FinTech**: Strong funding across **IPO**, decrease in **Series B**.
# > **CleanTech**: Moderate **private Equity** and **Seed**.
# > **AI & Machine Learning**: High funding across **IPO**, with **Series B** very low.
# > Similar is the case with **Blockchain** and **FoodTech**

# %% [markdown]
# ## **Lets check the Correlation between Employees and Funding, Funding Efficiency per Employee & Market Funding**

# %%
# Correlation between Employees and Funding
corr = np.corrcoef(df["Number_of_Employees"], df["Last_Funding_Amount_USD_Millions"])[0,1]
print("Correlation Analysis")
print("Correlation between employees and funding:", round(corr, 3))
if corr > 0.5:
    print("Strong positive relation: More employees generally means higher funding")
elif corr < -0.5:
    print("Strong negative relation: More employees tends to mean lower funding")
else:
    print("Weak/No clear relation between employees and funding")
print("==========================================================================")

# Funding Efficiency Funding per Employee 
df["Funding_per_Employee"] = df["Last_Funding_Amount_USD_Millions"] / df["Number_of_Employees"].replace(0, np.nan)
efficiency_stats = df.groupby("Industry")["Funding_per_Employee"].mean().sort_values(ascending=False)
print("Funding Efficiency by Industry")
print("Highest capital per employee:", efficiency_stats.idxmax(), "is", round(efficiency_stats.max(),2))
print("Lowest capital per employee:", efficiency_stats.idxmin(), "is", round(efficiency_stats.min(),2))
print("==========================================================================")

# Market Funding (Funding / Market Size)
df["Funding_to_Market_Ratio"] = df["Last_Funding_Amount_USD_Millions"] / df["Market_Size_Billion_USD"].replace(0, np.nan)
ratio_stats = df.groupby("Industry")["Funding_to_Market_Ratio"].mean().sort_values(ascending=False)
print("Funding relative to Market Size")
print("Industry most aggressive vs market size:", ratio_stats.idxmax(), "is", round(ratio_stats.max(),2))
print("Industry least aggressive vs market size:", ratio_stats.idxmin(), "is", round(ratio_stats.min(),2))
# Out:
# Correlation Analysis
# Correlation between employees and funding: 0.619
# Strong positive relation: More employees generally means higher funding
# ...
# Funding Efficiency by Industry
# Highest capital per employee: Cybersecurity is 1.14
# Lowest capital per employee: AI & Machine Learning is 0.54
# ...
# Funding relative to Market Size
# Industry most aggressive vs market size: Mobility is 6.22
# Industry least aggressive vs market size: E-commerce is 3.16

# %% [markdown]
# ## **Employees vs Funding Amount Visualization**

# %%
# Scatter plot of Number_of_Employees and Last_Funding_Amount_USD_Millions based on Industry and market size
fig = px.scatter(
    df, x='Number_of_Employees', y='Last_Funding_Amount_USD_Millions',
    color='Industry', size='Market_Size_Billion_USD',
    hover_data=['Company_Name', 'Funding_Stage'],
    title="Employees vs Funding Amount"
)
fig.show()

# %% [markdown]
# # Funding Correlation Insights
#
# ## Overall Trend
# > According to this Dataset, In general, startups with **more employees** donot tend to get **more funding**.
# > But  some **small teams** such as Food Tech and Mobility have **very low amount** of fundings
#
#
# ## Industry Differences
# > **FinTech and HealthTech**: According to this Dataset most often companies get **low funding** even with fewer number of employees. This shows that investors have less confidence in these areas.
# > **Social Media and E-commerce**: Usually have **small teams** and also receive **low fundings**.
#
# > **Gaming and CleanTech**: Show a **moderate behaviour**. Some companies raises with small teams, while others get much less, even with more number of employees.
# > Hence, there are different **business models** and **funding strategies** within these industries.
#
# ## Employee Counts
# > Many startups with about **500 to 2000 employees** have raised **low funding amounts**.
#
#
# ## Funding Range
# > Funding amounts are **very different across startups** according to this Dataset.
# > Some companies raise **hundreds of millions**, while others get much smaller amounts it does not matter how many employees these have

# %% [markdown]
# ## **Lets Analyze Core Technology Distribution Count**

# %%
# Top 10 Core Technologies
top_tech = df['Core_Technology'].value_counts()
display(top_tech)
# Out:
# Core_Technology
# Augmented Reality          225
# Machine Learning           224
# Edge Computing             219
# Virtual Reality            209
# Artificial Intelligence    208
# Deep Learning              206
# 5G                         206
# NLP                        203
# Cybersecurity              201
# IoT                        198
# Big Data                   197
# Cloud Computing            197
# Blockchain                 196
# Computer Vision            194
# Quantum Computing          186
# Name: count, dtype: int64

# %% [markdown]
# ## **Lets Visualize Top 10 Core Technologies**

# %%
# Custom vibrant color palette
custom_palette = ["#FF6F61", "#6B5B95", "#88B04B", "#F7CAC9", "#92A8D1",
    "#FFA500", "#00CED1", "#FF1493", "#8B0000"]

# Top 10 Core Technologies
top_tech = df['Core_Technology'].value_counts().nlargest(10)

plt.figure(figsize=(12,6))
ax = sns.barplot(
    x=top_tech.index,
    y=top_tech.values,
    palette=custom_palette
)

# Rotate x-ticks
plt.xticks(rotation=45, ha='right')

# Add values above bars
for i, value in enumerate(top_tech.values):
    ax.text(i, value + 0.5, str(value), ha='center', va='bottom', fontsize=10)

# Titles and labels
plt.title("Top 10 Core Technologies", fontsize=16)
plt.xlabel("Core Technology", fontsize=12)
plt.ylabel("Number of Startups", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Lets Analyze Funding Stage & Industry Stats**

# %%
# Funding Stage Summary
print("Total Funding by Stage")
funding_stage_summary = df.groupby("Funding_Stage")["Last_Funding_Amount_USD_Millions"].agg(
    ["sum", "mean", "median", "min", "max", "count"]
).sort_values("sum", ascending=False)
display(funding_stage_summary)

# Industry Summary
print("Total Funding by Industry")
industry_summary = df.groupby("Industry")["Last_Funding_Amount_USD_Millions"].agg(
    ["sum", "mean", "median", "min", "max", "count"]
).sort_values("sum", ascending=False)
display(industry_summary)

# Overall Stats
print("Overall Funding Distribution")
print("Total Funding (Millions USD):", np.sum(df["Last_Funding_Amount_USD_Millions"]))
print("Average Funding per Startup:", np.mean(df["Last_Funding_Amount_USD_Millions"]))
print("Median Funding per Startup:", np.median(df["Last_Funding_Amount_USD_Millions"]))
print("Largest Single Funding:", np.max(df["Last_Funding_Amount_USD_Millions"]))
print("Smallest Single Funding:", np.min(df["Last_Funding_Amount_USD_Millions"]))
# Out:
# Total Funding by Stage
#                       sum        mean   median    min     max  count
# Funding_Stage
# IPO             152168.23  452.881637  444.695  52.94  998.46    336
# Private Equity   78537.70  222.486402  197.180  50.59  498.65    353
# Series D         52080.88  155.465313  152.990  51.60  299.01    335
# Series C         27663.54   81.363353   73.815  30.68  149.86    340
# Seed             21809.13   31.561693   52.940   0.31   52.94    691
# Series B         12577.80   37.771171   39.850  10.05   59.95    333
# Series A          6814.68   20.281786   13.740   2.06   52.94    336
# Pre-Seed          5015.92   14.538899    1.010   0.05   52.94    345
# Total Funding by Industry
#                             sum        mean  median   min     max  count
# Industry
# Social Media           28540.34  128.560090   52.94  0.14  984.66    222
# EdTech                 26448.03  126.545598   52.94  0.22  997.28    209
# ...

# %% [markdown]
# ## **Lets Visualize Funding Stage and Last Funding amount based on Industry using Sunburst Plot**

# %%
# Sunburst plot of Funding Stage and Last Funding amount based on Industry
import plotly.express as px

fig = px.sunburst(
    df,
    path=['Funding_Stage', 'Industry'],  # hierarchy
    values='Last_Funding_Amount_USD_Millions',   # size by funding amount
    color='Industry',
    color_discrete_sequence=custom_palette,
    title='Funding Distribution by Stage and Industry'
)

fig.update_layout(margin=dict(t=50, l=0, r=0, b=0))
fig.show()

# %% [markdown]
# ## **Lets Analyze Industry Distribution Count**

# %%
# Count startups by industry
industry_counts = df["Industry"].value_counts()
display(industry_counts)
# Out:
# Industry
# Gaming                   223
# Social Media             222
# Mobility                 221
# Cybersecurity            213
# HealthTech               210
# PropTech                 210
# EdTech                   209
# AI & Machine Learning    201
# E-commerce               198
# FinTech                  197
# Blockchain               196
# SaaS                     195
# CleanTech                193
# Food Tech                192
# IoT                      189
# Name: count, dtype: int64

# %% [markdown]
#  ## **Distribution of Startups by Industry Visualization**

# %%
# Custom color palette
colors = ["#FF6F61", "#6B5B95", "#88B04B", "#F7CAC9", "#92A8D1",
    "#FFA500", "#00CED1", "#FF1493", "#8B0000"]

# Explode effect for slices (slightly separated)
explode = [0.05]*len(industry_counts)

# Pie chart
fig, ax = plt.subplots(figsize=(10, 7))

wedges, texts, autotexts = ax.pie(
    industry_counts.values,
    labels=industry_counts.index,
    autopct='%1.1f%%',           # percentage inside slices
    startangle=140,
    colors=colors[:len(industry_counts)],
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.5},
    explode=explode,
    pctdistance=0.75,            # distance of percentage from center
    labeldistance=1.05 ,          # distance of labels from center
    textprops={'fontsize': 10}
    
)

# Customize text inside slices
for autotext in autotexts:
    autotext.set_color('black')
    autotext.set_fontsize(8)
    autotext.set_fontweight('bold')

# Title
ax.set_title("Distribution of Startups by Industry", fontsize=16, fontweight='bold')

# Legend on the right
ax.legend(
    wedges,
    industry_counts.index,
    title="Industry",
    loc="center left",
    bbox_to_anchor=(1.05, 0.9),
    fontsize=8,
)

# Make layout tight
plt.tight_layout()
plt.show()

# %% [markdown]
# # Key Observations from Startup Funding Data
#
# ## Core Technologies
# > According to this Dataset the most common technologies are **Augmented Reality  which have 225 startups** and **Machine Learning have 224 startups**.
# > while other popular fields include **Edge Computing, Virtual Reality, Artificial Intelligence, Deep Learning, and 5G** each of them have 200+ startups.
# > Hence, advanced fields such as **Quantum Computing** have a strong presence of about 186 startups.
#
# ## Funding by Stage
# > **IPO stage startups** raise of about 471 million on an average, with the largest deals close to **1 billion**.
# > while **Private Equity and Series D** also show very large investments.
# > And **Seed and Pre-Seed** have much lower funding, as expected for very early-stage startups.
# > **Series A, B, and C** comes in between, and show how funding grows gradually.
#
# ## Funding by Industry
# > According to this Dataset **Social Media** has the highest average funding which is of about 156 million, and show strong investor interest.
# > while **E-commerce** has the lowest average of about 131 million, and even though it has one of the largest numbers of startups.
# > And **EdTech, PropTech, Gaming, Cybersecurity, and CleanTech** often have funding above than 140 million on average.
# > The **Food Tech and IoT** shows slightly lower averages but they are still significant.
#
# ## Overall Funding Distribution
# > According to this Dataset across all startups, the **total funding are of about 436,615 million USD (436 billion)**.
# > And the **average funding per startup** are of about 142 million, which is also close to the **median**.
# > And the **largest single deal** was nearly of about **1 billion i-e 998.46 million**.
# > The **smallest deal** was of about **0.05 million i-e: 50,000 USD**.
#
#
# ## Industry Size (Number of Startups)
# > **Gaming, Social Media, and Mobility** → largest, each with 220+ startups.
# > **Cybersecurity, HealthTech, and PropTech** → strong presence with 210+ startups.
# > **IoT, Food Tech, and CleanTech** → smaller but still significant (~190 startups each).
#
#
# > **Social Media** → both high funding and a large number of startups.
# > **E-commerce** → many startups but lower average funding (investment spread more thinly).
# > **PropTech** → shows the **biggest funding gap** (some raise huge sums, others much less).
# > Most startups cluster around **142 million in funding**, but outliers raise either extremely high or very low amounts.

# %% [markdown]
# ## **Remove ID Column which is not useful for Model**

# %%
# Identify columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# Remove ID column from encoding/scaling
if 'Startup_ID' in num_cols:
    num_cols.remove('Startup_ID')
if 'Startup_ID' in cat_cols:
    cat_cols.remove('Startup_ID')

# %% [markdown]
# ## **Encode Categorical Columns**

# %%
# Label encoding for categorical/object columns
le_dict = {}
for col in cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    le_dict[col] = le  # save encoders if needed later

# %% [markdown]
# ## **Feature engineering**

# %%
# Feature engineering
# Age of startup
if 'Founding_Year' in df.columns:
    df['Startup_Age'] = 2025 - df['Founding_Year']

# Presence of social media / website
df['Has_Website'] = df['Website'].apply(lambda x: 0 if x==0 else 1)
df['Has_LinkedIn'] = df['LinkedIn_Profile'].apply(lambda x: 0 if x==0 else 1)
df['Has_Twitter'] = df['Twitter_Handle'].apply(lambda x: 0 if x==0 else 1)

# Funding per employee
if 'Last_Funding_Amount_USD_Millions' in df.columns and 'Number_of_Employees' in df.columns:
    df['Funding_per_Employee'] = df['Last_Funding_Amount_USD_Millions'] / (df['Number_of_Employees'] + 1)

# Market size normalized
if 'Market_Size_Billion_USD' in df.columns:
    df['Market_Size_Normalized'] = (df['Market_Size_Billion_USD'] - df['Market_Size_Billion_USD'].mean()) / df['Market_Size_Billion_USD'].std()

# Final processed dataframe
display(df.head())
# Out:
#    Startup_ID  Company_Name  Industry  One_Line_Pitch  Founding_Year  \
# 0           1          2192        14             713           2016
# 1           2           573         5             593           2014
# 2           3           212        13             268           2018
# 3           4          1131        10               4           2017
# 4           5           332        11             777           2016
#
#    Headquarters_Location  Funding_Stage  Last_Funding_Amount_USD_Millions  \
# 0                   1045              1                          0.250000
# 1                   1564              1                          1.070000
# 2                   1987              5                        142.266136
# 3                   1250              3                          3.190000
# 4                     99              3                          4.210000
#
#    Number_of_Employees  Website  ...  CEO_Name  Core_Technology  \
# ...

# %% [markdown]
# ## **Define Features and Target Variables and Handle Class Imbalance**

# %%
# Define Features and Target
X = df.drop(columns=['Funding_Stage'])  # Features
y = df['Funding_Stage']                 # Target

# Encode categorical variables if needed
for col in X.select_dtypes(include='object').columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))

# Handle Class Imbalance by Upsampling
df_full = pd.concat([X, y], axis=1)
max_count = y.value_counts().max()

df_list = []
for cls in y.unique():
    df_cls = df_full[df_full['Funding_Stage'] == cls]
    df_cls_upsampled = df_cls.sample(max_count, replace=True, random_state=42)
    df_list.append(df_cls_upsampled)

df_resampled = pd.concat(df_list)

X_res = df_resampled.drop(columns=['Funding_Stage'])
y_res = df_resampled['Funding_Stage']

# %% [markdown]
# ## **Train and Evaluate KNN, Decision Tree & Random Forest**

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42, stratify=y_res)

# Initialize models
models = {
    'KNN': KNeighborsClassifier(n_neighbors=5, weights='distance'),
    'Decision_Tree': DecisionTreeClassifier(random_state=42),
    'Random_Forest': RandomForestClassifier(n_estimators=100, random_state=42)
}

# Dictionary to store performance metrics
performance = {}

# Train and evaluate each model
for name, model in models.items():
    # For KNN, apply scaling + PCA
    if name == 'KNN':
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        pca = PCA(n_components=0.95, random_state=42)
        X_train_pca = pca.fit_transform(X_train_scaled)
        X_test_pca = pca.transform(X_test_scaled)

        model.fit(X_train_pca, y_train)
        y_pred = model.predict(X_test_pca)
    else:
        # Decision Tree / Random Forest
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
    
    # Calculate metrics
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='macro')
    rec = recall_score(y_test, y_pred, average='macro')
    f1 = f1_score(y_test, y_pred, average='macro')
    
    performance[name] = {'Accuracy': acc, 'Precision': prec, 'Recall': rec, 'F1-score': f1}
    
    # Print metrics
    print(f"\n================={name} =====================")
    print("Accuracy:", acc)
    print("Precision (macro):", prec)
    print("Recall (macro):", rec)
    print("F1-score (macro):", f1)
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Create DataFrame for heatmap
perf_df = pd.DataFrame(performance).T  # transpose to have models as rows
plt.figure(figsize=(8, 6))
sns.heatmap(perf_df, annot=True, cmap='viridis', fmt=".3f")
plt.title("Model Performance Comparison")
plt.show()
# Out:
# =================KNN =====================
# Accuracy: 0.8164556962025317
# Precision (macro): 0.816663381644555
# Recall (macro): 0.8166770931081222
# F1-score (macro): 0.8142302830796884
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       138
#            1       0.86      0.85      0.85       138
#            2       0.83      0.86      0.84       138
#            3       0.78      0.58      0.66       139
#            4       0.77      0.87      0.82       138
#            5       0.79      0.83      0.81       138
#            6       0.76      0.81      0.79       139
#            7       0.82      0.82      0.82       138
#
#     accuracy                           0.82      1106
#    macro avg       0.82      0.82      0.81      1106
# weighted avg       0.82      0.82      0.81      1106
#
# Confusion Matrix:
#  [[128   0   4   0   3   1   2   0]
#  [  0 117   0   4   7   3   2   5]
# ...

# %% [markdown]
# ## **Hyperparameter Tuning, Model Evaluation, & Comparison, Stacking & Ensembling**

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42, stratify=y_res)

# Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# KNN Hyperparameter Tuning
knn = KNeighborsClassifier()

param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_search = GridSearchCV(knn, param_grid, cv=cv_strategy, scoring='f1_macro', n_jobs=1)
grid_search.fit(X_train_scaled, y_train)

best_knn = grid_search.best_estimator_
print("Best KNN parameters:", grid_search.best_params_)

# Other Models
dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Voting Ensemble
voting_clf = VotingClassifier(
    estimators=[('rf', rf), ('dt', dt), ('knn', best_knn)],
    voting='soft',
    weights=[3, 2, 1] 
)
voting_clf.fit(X_train_scaled, y_train)

# Stacking Ensemble
stacking_clf = StackingClassifier(
    estimators=[('rf', rf), ('dt', dt), ('knn', best_knn)],
    final_estimator=LogisticRegression(max_iter=1000, random_state=42),
    passthrough=True,
    n_jobs=-1
)
stacking_clf.fit(X_train_scaled, y_train)

# Evaluation Function
def evaluate_model(name, model, X_test, y_test):
    y_pred = model.predict(X_test)
    print(f"\n=== {name} ===")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Precision (macro):", precision_score(y_test, y_pred, average='macro'))
    print("Recall (macro):", recall_score(y_test, y_pred, average='macro'))
    print("F1-score (macro):", f1_score(y_test, y_pred, average='macro'))
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Run Evaluations
evaluate_model("Best KNN", best_knn, X_test_scaled, y_test)
evaluate_model("Decision Tree", dt.fit(X_train_scaled, y_train), X_test_scaled, y_test)
evaluate_model("Random Forest", rf.fit(X_train_scaled, y_train), X_test_scaled, y_test)
evaluate_model("Voting Ensemble", voting_clf, X_test_scaled, y_test)
evaluate_model("Stacking Ensemble", stacking_clf, X_test_scaled, y_test)

# Compare Results in Table
models = {
    "KNN": best_knn,
    "Decision Tree": dt,
    "Random Forest": rf,
    "Voting Ensemble": voting_clf,
    "Stacking Ensemble": stacking_clf
}

results = {}
for name, model in models.items():
    y_pred = model.predict(X_test_scaled)
    results[name] = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average='macro'),
        "Recall": recall_score(y_test, y_pred, average='macro'),
        "F1": f1_score(y_test, y_pred, average='macro')
    }

results_df = pd.DataFrame(results).T
print("\n========================= Performance Comparison ==========================\n")
print(results_df)

# Heatmap for visualization
plt.figure(figsize=(8,5))
sns.heatmap(results_df, annot=True, fmt=".3f", cmap="viridis")
plt.title("Model Performance Comparison", fontsize=14)
plt.show()
# Out:
# Best KNN parameters: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
#
# === Best KNN ===
# Accuracy: 0.8291139240506329
# Precision (macro): 0.8297755340848003
# Recall (macro): 0.8292996037952247
# F1-score (macro): 0.8281106384665435
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94       138
#            1       0.84      0.86      0.85       138
#            2       0.85      0.87      0.86       138
#            3       0.78      0.63      0.69       139
#            4       0.85      0.87      0.86       138
#            5       0.77      0.83      0.80       138
#            6       0.78      0.83      0.80       139
#            7       0.82      0.84      0.83       138
#
#     accuracy                           0.83      1106
#    macro avg       0.83      0.83      0.83      1106
# weighted avg       0.83      0.83      0.83      1106
#
# Confusion Matrix:
# ...

# %% [markdown]
# ## **ROC Curve Comparison of All Models**

# %%
# One-hot encode y_test for multiclass ROC
classes = np.unique(y_test)
y_test_bin = label_binarize(y_test, classes=classes)

# Plot ROC curves for all models
plt.figure(figsize=(10, 8))

for name, model in models.items():
    # Predict probabilities
    y_proba = model.predict_proba(X_test_scaled)

    # Compute ROC curve and AUC for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i, c in enumerate(classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_proba[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    
    # Compute macro-average AUC
    all_fpr = np.unique(np.concatenate([fpr[i] for i in classes]))
    mean_tpr = np.zeros_like(all_fpr)
    for i in classes:
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
    mean_tpr /= len(classes)
    roc_auc_macro = auc(all_fpr, mean_tpr)

    # Plot macro ROC
    plt.plot(all_fpr, mean_tpr, lw=2, label=f'{name} (AUC = {roc_auc_macro:.3f})')

# Plot diagonal
plt.plot([0, 1], [0, 1], linestyle='--', color='grey', lw=2)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('ROC Curve Comparison All Models', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## **Lets Implement RandomSearchCV and Evaluate Models performance**

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42, stratify=y_res)


# Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# KNN Randomized Search CV
knn = KNeighborsClassifier()

param_dist = {
    'n_neighbors': randint(3, 15),  # sample integers from 3 to 15
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

random_search = RandomizedSearchCV(
    knn,
    param_distributions=param_dist,
    n_iter=20,  # number of random combinations to try
    cv=cv_strategy,
    scoring='f1_macro',
    n_jobs=-1,
    random_state=42
)
random_search.fit(X_train_scaled, y_train)

best_knn = random_search.best_estimator_
print("Best KNN parameters:", random_search.best_params_)

# Other Models
dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Voting Ensemble
voting_clf = VotingClassifier(
    estimators=[('rf', rf), ('dt', dt), ('knn', best_knn)],
    voting='soft',
    weights=[3, 2, 1])
voting_clf.fit(X_train_scaled, y_train)

# Stacking Ensemble
stacking_clf = StackingClassifier(
    estimators=[('rf', rf), ('dt', dt), ('knn', best_knn)],
    final_estimator=LogisticRegression(max_iter=1000, random_state=42),
    passthrough=True,
    n_jobs=-1
)
stacking_clf.fit(X_train_scaled, y_train)

# Evaluation Function
def evaluate_model(name, model, X_test, y_test):
    y_pred = model.predict(X_test)
    print(f"\n=== {name} ===")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Precision (macro):", precision_score(y_test, y_pred, average='macro'))
    print("Recall (macro):", recall_score(y_test, y_pred, average='macro'))
    print("F1-score (macro):", f1_score(y_test, y_pred, average='macro'))
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Run Evaluations
evaluate_model("Best KNN", best_knn, X_test_scaled, y_test)
evaluate_model("Decision Tree", dt.fit(X_train_scaled, y_train), X_test_scaled, y_test)
evaluate_model("Random Forest", rf.fit(X_train_scaled, y_train), X_test_scaled, y_test)
evaluate_model("Voting Ensemble", voting_clf, X_test_scaled, y_test)
evaluate_model("Stacking Ensemble", stacking_clf, X_test_scaled, y_test)

# Compare Results in Table
models = {
    "KNN": best_knn,
    "Decision Tree": dt,
    "Random Forest": rf,
    "Voting Ensemble": voting_clf,
    "Stacking Ensemble": stacking_clf
}

results = {}
for name, model in models.items():
    y_pred = model.predict(X_test_scaled)
    results[name] = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average='macro'),
        "Recall": recall_score(y_test, y_pred, average='macro'),
        "F1": f1_score(y_test, y_pred, average='macro')
    }

results_df = pd.DataFrame(results).T
print("\n=============================Performance Comparison=======================\n")
print(results_df)

# Heatmap for visualization
plt.figure(figsize=(8,5))
sns.heatmap(results_df, annot=True, fmt=".3f", cmap="viridis")
plt.title("Model Performance Comparison", fontsize=14)
plt.show()
# Out:
# Best KNN parameters: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
#
# === Best KNN ===
# Accuracy: 0.8291139240506329
# Precision (macro): 0.8297755340848003
# Recall (macro): 0.8292996037952247
# F1-score (macro): 0.8281106384665435
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94       138
#            1       0.84      0.86      0.85       138
#            2       0.85      0.87      0.86       138
#            3       0.78      0.63      0.69       139
#            4       0.85      0.87      0.86       138
#            5       0.77      0.83      0.80       138
#            6       0.78      0.83      0.80       139
#            7       0.82      0.84      0.83       138
#
#     accuracy                           0.83      1106
#    macro avg       0.83      0.83      0.83      1106
# weighted avg       0.83      0.83      0.83      1106
#
# Confusion Matrix:
# ...

# %%
# Train-test split 
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42, stratify=y_res)

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Binarize output for multiclass ROC
classes = np.unique(y_test)
y_test_bin = label_binarize(y_test, classes=classes)

# Dictionary to store AUC scores
auc_scores = {}

# Plot ROC curves for all models
plt.figure(figsize=(10, 8))

for name, model in models.items():
    # Train the model on the scaled training set
    model.fit(X_train_scaled, y_train)
    
    # Predict probabilities
    y_score = model.predict_proba(X_test_scaled)
    
    # Compute ROC per class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i, c in enumerate(classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    
    # Macro-average ROC
    all_fpr = np.unique(np.concatenate([fpr[i] for i in classes]))
    mean_tpr = np.zeros_like(all_fpr)
    for i in classes:
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
    mean_tpr /= len(classes)
    roc_auc_macro = auc(all_fpr, mean_tpr)
    
    auc_scores[name] = roc_auc_macro
    
    # Plot ROC curve
    plt.plot(all_fpr, mean_tpr, lw=2, label=f'{name} (AUC = {roc_auc_macro:.3f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multiclass ROC Curves')
plt.legend(loc="lower right")
plt.show()

# Create DataFrame of AUC scores
auc_df = pd.DataFrame(list(auc_scores.items()), columns=['Model', 'ROC_AUC'])
print("\n=============== ROC AUC Scores =======================\n")
print(auc_df)
# Out:
# =============== ROC AUC Scores =======================
#
#                Model   ROC_AUC
# 0                KNN  0.942700
# 1      Decision Tree  0.957670
# 2      Random Forest  0.997369
# 3    Voting Ensemble  0.997002
# 4  Stacking Ensemble  0.996779

# %%
# Find the best-performing model 
best_model_name = max(auc_scores, key=auc_scores.get)
best_model = models[best_model_name]

# Train the best model
best_model.fit(X_train_scaled, y_train)

# Predict probabilities
y_score = best_model.predict_proba(X_test_scaled)

# Compute ROC per class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i, c in enumerate(classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Macro-average ROC
all_fpr = np.unique(np.concatenate([fpr[i] for i in classes]))
mean_tpr = np.zeros_like(all_fpr)
for i in classes:
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
mean_tpr /= len(classes)
roc_auc_macro = auc(all_fpr, mean_tpr)

# Plot ROC curve for the best model
plt.figure(figsize=(8, 6))
plt.plot(all_fpr, mean_tpr, lw=2, label=f'{best_model_name} (AUC = {roc_auc_macro:.3f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve of Best Performing Model: {best_model_name}')
plt.legend(loc="lower right")
plt.show()

print(f"\nBest Model: {best_model_name} with Macro-average ROC AUC = {roc_auc_macro:.3f}")
# Out:
# Best Model: Random Forest with Macro-average ROC AUC = 0.997

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42, stratify=y_res)

classes = np.unique(y_test)


# Scale and PCA for KNN
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

pca = PCA(n_components=0.95, random_state=42)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# Default Models
default_models = {
    'KNN': KNeighborsClassifier(n_neighbors=5, weights='distance'),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42)
}

default_results = {}
for name, model in default_models.items():
    if name == 'KNN':
        model.fit(X_train_pca, y_train)
        y_pred = model.predict(X_test_pca)
        y_prob = model.predict_proba(X_test_pca)
    else:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)
    
    y_test_bin = label_binarize(y_test, classes=classes)
    roc_auc_macro = roc_auc_score(y_test_bin, y_prob, average='macro', multi_class='ovr')

    default_results[name] = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred, average='macro'),
        'Recall': recall_score(y_test, y_pred, average='macro'),
        'F1': f1_score(y_test, y_pred, average='macro'),
        'ROC_AUC': roc_auc_macro
    }

# Tuned Models 
# RandomizedSearchCV
cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# KNN tuned
knn_param_dist = {
    'n_neighbors': randint(3, 20),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}
knn_search = RandomizedSearchCV(
    KNeighborsClassifier(),
    knn_param_dist,
    n_iter=30,
    cv=cv_strategy,
    scoring='f1_macro',
    n_jobs=-1,
    random_state=42
)
knn_search.fit(X_train_pca, y_train)
best_knn = knn_search.best_estimator_

# Decision Tree tuned
dt_param_dist = {
    'max_depth': randint(3, 20),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10),
    'criterion': ['gini', 'entropy']
}
best_dt = RandomizedSearchCV(
    DecisionTreeClassifier(random_state=42),
    dt_param_dist,
    n_iter=30,
    cv=cv_strategy,
    scoring='f1_macro',
    n_jobs=-1,
    random_state=42
).fit(X_train, y_train).best_estimator_

# Random Forest tuned
rf_param_dist = {
    'n_estimators': randint(50, 300),
    'max_depth': randint(3, 20),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10),
    'max_features': ['auto', 'sqrt', 'log2']
}
best_rf = RandomizedSearchCV(
    RandomForestClassifier(random_state=42),
    rf_param_dist,
    n_iter=30,
    cv=cv_strategy,
    scoring='f1_macro',
    n_jobs=-1,
    random_state=42
).fit(X_train, y_train).best_estimator_

tuned_models = {
    'KNN': best_knn,
    'Decision Tree': best_dt,
    'Random Forest': best_rf
}

tuned_results = {}
for name, model in tuned_models.items():
    if name == 'KNN':
        y_pred = model.predict(X_test_pca)
        y_prob = model.predict_proba(X_test_pca)
    else:
        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)
    
    y_test_bin = label_binarize(y_test, classes=classes)
    roc_auc_macro = roc_auc_score(y_test_bin, y_prob, average='macro', multi_class='ovr')

    tuned_results[name] = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred, average='macro'),
        'Recall': recall_score(y_test, y_pred, average='macro'),
        'F1': f1_score(y_test, y_pred, average='macro'),
        'ROC_AUC': roc_auc_macro
    }

# Combine Results
metrics = ['Accuracy', 'Precision', 'Recall', 'F1', 'ROC_AUC']
comparison_data = {}
for metric in metrics:
    comparison_data[metric] = []
    for name in default_results.keys():
        comparison_data[metric].append(default_results[name][metric])
        comparison_data[metric].append(tuned_results[name][metric])

comparison_df = pd.DataFrame(
    comparison_data,
    index=[f"{name} Default" for name in default_results.keys()] + [f"{name} Tuned" for name in tuned_results.keys()]
)

print("\n=== Default vs Tuned Models Comparison ===\n")
print(comparison_df)

# Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(comparison_df, annot=True, fmt=".3f", cmap="viridis")
plt.title("Default vs Tuned Models - All Metrics", fontsize=14)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %% [markdown]
# **Best Performing Model Observations**
#
# while predicting performance of **KNN, Decision Tree, and Random Forest** it is detrmined that
# **KNN**
# - KNN have Accuracy of about: 82.9%
# - Its ROC-AUC Score is: 0.9427
#
# **Decision Tree**
# - Decision Tree have Accuracy of about: 92.6%
# - Its ROC-AUC Score is: 0.9577
#
# **Random Forest**
# - Random Forest have Accuracy of about: 94.2%
# - Its ROC-AUC Score is: 0.9974
# `Random Forest is the best. It is more accurate and reliable because it combines many trees, which reduces mistakes and gives very high ROC-AUC`.
#
# **Why Random Forest is the best:**
# - Combines many Decision Trees and have less chance of errors.
# - Handles complex patterns better than KNN and a single Decision Tree.
# - Very high ROC-AUC of about 0.9974 it separates classes almost perfectly.

# %% [markdown]
# ## **Default vs Tuned Models Comparison**

# %% [markdown]
# | Model                  | Accuracy  | Precision | Recall   | F1       | ROC_AUC  |
# |------------------------|-----------|-----------|----------|----------|----------|
# | KNN Default            | 0.816456  | 0.816663  | 0.816677 | 0.814230 | 0.920008 |
# | Decision Tree Default  | 0.820072  | 0.819502  | 0.820281 | 0.818321 | 0.932425 |
# | Random Forest Default  | 0.925859  | 0.926291  | 0.925933 | 0.925843 | 0.957670 |
# | KNN Tuned              | 0.905063  | 0.907946  | 0.905113 | 0.905720 | 0.968282 |
# | Decision Tree Tuned    | 0.942134  | 0.943806  | 0.942192 | 0.942472 | 0.997342 |
# | Random Forest Tuned    | 0.917722  | 0.921829  | 0.917761 | 0.918518 | 0.994331 |
